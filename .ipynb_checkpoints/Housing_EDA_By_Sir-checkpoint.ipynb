# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pwd
# Out:
# 'C:\\Users\\hp\\Downloads'

# %%
housing = pd.read_csv('Housing dataset.csv')

# %%
type(housing)
# Out:
# pandas.core.frame.DataFrame

# %%
housing.head(10)
# Out:
#    Id  OverallQual  YearBuilt  TotalBsmtSF Electrical  GrLivArea  FullBath  \
# 0   1            7       2003          856      SBrkr       1710         2
# 1   2            6       1976         1262      SBrkr       1262         2
# 2   3            7       2001          920      SBrkr       1786         2
# 3   4            7       1915          756      SBrkr       1717         1
# 4   5            8       2000         1145      SBrkr       2198         2
# 5   6            5       1993          796      SBrkr       1362         1
# 6   7            8       2004         1686      SBrkr       1694         2
# 7   8            7       1973         1107      SBrkr       2090         2
# 8   9            5       1939          991      SBrkr       1077         1
# 9  10            5       1965         1040      SBrkr       1040         1
#
#   GarageType  GarageCars  GarageArea  Fence MiscFeature  SalePrice
# 0     Attchd           2         548    NaN         NaN     208500
# ...

# %%
housing.tail()
# Out:
#         Id  OverallQual  YearBuilt  TotalBsmtSF Electrical  GrLivArea  \
# 1413  1414            6       1999          953      SBrkr       1647
# 1414  1415            6       1978         1542      SBrkr       2073
# 1415  1416            7       1941         1152      SBrkr       2340
# 1416  1417            5       1950         1078      FuseA       1078
# 1417  1418            5       1965         1256      SBrkr       1256
#
#       FullBath GarageType  GarageCars  GarageArea  Fence MiscFeature  \
# 1413         2     Attchd           2         460    NaN         NaN
# 1414         2     Attchd           2         500  MnPrv         NaN
# 1415         2     Attchd           1         252  GdPrv        Shed
# 1416         1        NaN           1         240    NaN         NaN
# 1417         1     Attchd           1         276    NaN         NaN
#
#       SalePrice
# 1413     175000
# 1414     210000
# 1415     266500
# 1416     142125
# 1417     147500

# %%
housing.shape
# Out:
# (1418, 13)

# %%
print('The dataset has rows=',(housing.shape[0]))
print('The dataset has columns=',(housing.shape[1]))
# Out:
# The dataset has rows= 1418
# The dataset has columns= 13

# %%
housing.dtypes
# Out:
# Id              int64
# OverallQual     int64
# YearBuilt       int64
# TotalBsmtSF     int64
# Electrical     object
# GrLivArea       int64
# FullBath        int64
# GarageType     object
# GarageCars      int64
# GarageArea      int64
# Fence          object
# MiscFeature    object
# SalePrice       int64
# dtype: object

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1418 entries, 0 to 1417
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id           1418 non-null   int64
#  1   OverallQual  1418 non-null   int64
#  2   YearBuilt    1418 non-null   int64
#  3   TotalBsmtSF  1418 non-null   int64
#  4   Electrical   1417 non-null   object
#  5   GrLivArea    1418 non-null   int64
#  6   FullBath     1418 non-null   int64
#  7   GarageType   1275 non-null   object
#  8   GarageCars   1418 non-null   int64
#  9   GarageArea   1418 non-null   int64
#  10  Fence        270 non-null    object
#  11  MiscFeature  52 non-null     object
#  12  SalePrice    1418 non-null   int64
# dtypes: int64(9), object(4)
# memory usage: 144.1+ KB

# %%
housing.describe().transpose()
# Out:
#               count           mean           std      min        25%  \
# Id           1418.0     709.500000    409.485653      1.0     355.25
# OverallQual  1418.0       6.114245      1.385858      1.0       5.00
# YearBuilt    1418.0    1971.600846     30.064293   1872.0    1954.00
# TotalBsmtSF  1418.0    1061.712271    437.277589      0.0     796.50
# GrLivArea    1418.0    1519.645275    527.412584    334.0    1132.50
# FullBath     1418.0       1.565585      0.551127      0.0       1.00
# GarageCars   1418.0       1.763752      0.755995      0.0       1.00
# GarageArea   1418.0     472.617772    216.068677      0.0     324.25
# SalePrice    1418.0  182089.485896  79970.934085  34900.0  130000.00
#
#                   50%        75%       max
# Id              709.5    1063.75    1418.0
# OverallQual       6.0       7.00      10.0
# YearBuilt      1973.0    2001.00    2010.0
# TotalBsmtSF     994.0    1303.50    6110.0
# GrLivArea      1468.5    1786.00    5642.0
# ...

# %%
housing.describe(include='object').transpose()
# Out:
#             count unique     top  freq
# Electrical   1417      5   SBrkr  1300
# GarageType   1275      6  Attchd   800
# Fence         270      4   MnPrv   148
# MiscFeature    52      4    Shed    47

# %%
housing.corr()  # value lies b/w -1 to 1
# Out:
#                    Id  OverallQual  YearBuilt  TotalBsmtSF  GrLivArea  \
# Id           1.000000    -0.029188  -0.017960    -0.019396   0.002991
# OverallQual -0.029188     1.000000   0.584692     0.545747   0.592881
# YearBuilt   -0.017960     0.584692   1.000000     0.396971   0.204757
# TotalBsmtSF -0.019396     0.545747   0.396971     1.000000   0.456365
# GrLivArea    0.002991     0.592881   0.204757     0.456365   1.000000
# FullBath    -0.000113     0.550112   0.478441     0.326705   0.626942
# GarageCars   0.015633     0.609104   0.550275     0.442614   0.472139
# GarageArea   0.014457     0.567796   0.492807     0.495600   0.470736
# SalePrice   -0.029967     0.791478   0.528006     0.619852   0.709503
#
#              FullBath  GarageCars  GarageArea  SalePrice
# Id          -0.000113    0.015633    0.014457  -0.029967
# OverallQual  0.550112    0.609104    0.567796   0.791478
# YearBuilt    0.478441    0.550275    0.492807   0.528006
# ...

# %%
sns.heatmap(housing.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
housing.count()
# Out:
# Id             1418
# OverallQual    1418
# YearBuilt      1418
# TotalBsmtSF    1418
# Electrical     1417
# GrLivArea      1418
# FullBath       1418
# GarageType     1275
# GarageCars     1418
# GarageArea     1418
# Fence           270
# MiscFeature      52
# SalePrice      1418
# dtype: int64

# %%
housing.nunique()
# Out:
# Id             1418
# OverallQual      10
# YearBuilt       110
# TotalBsmtSF     717
# Electrical        5
# GrLivArea       854
# FullBath          4
# GarageType        6
# GarageCars        5
# GarageArea      440
# Fence             4
# MiscFeature       4
# SalePrice       653
# dtype: int64

# %%
housing_1995 = housing[housing['YearBuilt']== 1995]

# %%
housing_1995
# Out:
#         Id  OverallQual  YearBuilt  TotalBsmtSF Electrical  GrLivArea  \
# 76      77            7       1995          384      SBrkr       1474
# 194    195            5       1995          990      SBrkr        990
# 207    208            7       1995         1203      SBrkr       2520
# 212    213            8       1995         1462      SBrkr       2794
# 336    337            6       1995         1200      SBrkr       1200
# 383    384            6       1995          806      SBrkr       1572
# 629    630            8       1995         2109      SBrkr       2113
# 703    704            8       1995         1595      SBrkr       1616
# 732    733            8       1995         1318      SBrkr       2531
# 737    738            8       1995         1494      SBrkr       1494
# 752    753            7       1995         1237      SBrkr       1253
# 809    810            5       1995         1099      SBrkr       1099
# ...

# %%
housing_1995.shape
# Out:
# (18, 13)

# %%
housing[(housing['OverallQual']==10) & (housing['YearBuilt']> 2005)]
# Out:
#         Id  OverallQual  YearBuilt  TotalBsmtSF Electrical  GrLivArea  \
# 55      56           10       2006         1410      SBrkr       2945
# 369    370           10       2007         1682      SBrkr       2332
# 419    420           10       2008         3094      SBrkr       2402
# 493    494           10       2009         2006      SBrkr       2020
# 500    501           10       2007         3138      SBrkr       4676
# 567    568           10       2008         1722      SBrkr       2296
# 797    798           10       2007         2078      SBrkr       2084
# 962    963           10       2006         1700      SBrkr       1718
# 1207  1208           10       2006         2076      SBrkr       2076
# 1260  1261           10       2008         6110      SBrkr       5642
# 1400  1401           10       2008         1017      SBrkr       2007
#
#       FullBath GarageType  GarageCars  GarageArea Fence MiscFeature  SalePrice
# ...

# %%
housing.isnull().sum()
# Out:
# Id                0
# OverallQual       0
# YearBuilt         0
# TotalBsmtSF       0
# Electrical        1
# GrLivArea         0
# FullBath          0
# GarageType      143
# GarageCars        0
# GarageArea        0
# Fence          1148
# MiscFeature    1366
# SalePrice         0
# dtype: int64

# %%
sns.countplot(x='Fence', data=housing)
# Out:
# <AxesSubplot:xlabel='Fence', ylabel='count'>

# %%
sns.countplot(x='MiscFeature', data=housing)
# Out:
# <AxesSubplot:xlabel='MiscFeature', ylabel='count'>

# %%
sns.countplot(x='Electrical', data=housing)
# Out:
# <AxesSubplot:xlabel='Electrical', ylabel='count'>

# %%
housing['Electrical'].mode()
# Out:
# 0    SBrkr
# dtype: object

# %%
# housing['Electrical'].fillna('SBrkr', inplace=True)

# %%
housing['Electrical']= np.where(housing["Electrical"].isnull(),'SBrkr',housing['Electrical'])

# %%
housing['Electrical'].isnull().sum()
# Out:
# 0

# %%
housing.isnull().sum()
# Out:
# Id                0
# OverallQual       0
# YearBuilt         0
# TotalBsmtSF       0
# Electrical        0
# GrLivArea         0
# FullBath          0
# GarageType      143
# GarageCars        0
# GarageArea        0
# Fence          1148
# MiscFeature    1366
# SalePrice         0
# dtype: int64

# %%
housing.drop(columns=['MiscFeature','Fence'], inplace=True)

# %%
housing.isnull().sum()
# Out:
# Id               0
# OverallQual      0
# YearBuilt        0
# TotalBsmtSF      0
# Electrical       0
# GrLivArea        0
# FullBath         0
# GarageType     143
# GarageCars       0
# GarageArea       0
# SalePrice        0
# dtype: int64

# %%
housing[housing['GarageType'].isnull()]
# Out:
#         Id  OverallQual  YearBuilt  TotalBsmtSF Electrical  GrLivArea  \
# 8        9            5       1939          991      SBrkr       1077
# 22      23            5       1968         1060      SBrkr       1060
# 26      27            5       1957         1484      SBrkr       1600
# 37      38            4       1955            0      FuseP       1152
# 39      40            5       1959         1350      SBrkr       1328
# ...    ...          ...        ...          ...        ...        ...
# 1387  1388            5       1940          788      SBrkr        804
# 1407  1408            5       1970          630      SBrkr        630
# 1408  1409            5       1974          896      SBrkr       1792
# 1411  1412            5       2006         1140      SBrkr       1140
# 1416  1417            5       1950         1078      FuseA       1078
#
#       FullBath GarageType  GarageCars  GarageArea  SalePrice
# 8            1        NaN           1         205     118000
# ...

# %%
housing.groupby('GarageType').median()
# Out:
#                Id  OverallQual  YearBuilt  TotalBsmtSF  GrLivArea  FullBath  \
# GarageType
# 2Types      767.5          5.0     1959.5       1172.0     1698.0       1.5
# Attchd      737.5          7.0     1993.0       1176.0     1565.0       2.0
# Basment     999.0          6.0     1957.0        920.0     1431.0       1.0
# BuiltIn     613.0          7.0     2003.0        956.0     2035.0       2.0
# CarPort     535.0          4.0     1962.0        816.0     1296.0       1.0
# Detchd      699.0          5.0     1946.0        842.0     1214.0       1.0
#
#             GarageCars  GarageArea  SalePrice
# GarageType
# 2Types             3.0       825.0   159000.0
# Attchd             2.0       514.0   189500.0
# Basment            2.0       450.0   148000.0
# BuiltIn            2.0       554.0   230000.0
# CarPort            2.0       462.0   108000.0
# Detchd             1.0       396.0   129000.0

# %%
housing.groupby('GarageType')['GarageCars'].describe()
# Out:
#             count      mean       std  min  25%  50%  75%  max
# GarageType
# 2Types        6.0  3.000000  0.632456  2.0  3.0  3.0  3.0  4.0
# Attchd      800.0  2.043750  0.554274  1.0  2.0  2.0  2.0  4.0
# Basment      19.0  1.578947  0.507257  1.0  1.0  2.0  2.0  2.0
# BuiltIn      87.0  2.252874  0.614143  1.0  2.0  2.0  3.0  3.0
# CarPort       9.0  1.666667  0.500000  1.0  1.0  2.0  2.0  2.0
# Detchd      354.0  1.539548  0.592556  1.0  1.0  1.0  2.0  4.0

# %%
sns.countplot('GarageType',data= housing, hue= 'GarageCars')
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GarageType', ylabel='count'>

# %%
missing_garage = housing[housing['GarageType'].isnull()]

# %%
sns.countplot('GarageCars', data=missing_garage)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GarageCars', ylabel='count'>

# %%
missing_garage['GarageCars'].value_counts()
# Out:
# 0    81
# 1    62
# Name: GarageCars, dtype: int64

# %%
housing['GarageType']= np.where((housing['GarageType'].isnull() & (housing['GarageCars']==0)),'NoGarage', housing['GarageType'])

# %%
housing[housing['GarageType'].isnull()]['GarageCars'].value_counts()
# Out:
# 1    62
# Name: GarageCars, dtype: int64

# %%
housing['GarageType']= np.where((housing['GarageType'].isnull() & (housing['GarageCars']==1)),'Detchd', housing['GarageType'])

# %%
housing.isnull().sum()
# Out:
# Id             0
# OverallQual    0
# YearBuilt      0
# TotalBsmtSF    0
# Electrical     0
# GrLivArea      0
# FullBath       0
# GarageType     0
# GarageCars     0
# GarageArea     0
# SalePrice      0
# dtype: int64
